# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
symbol = "ADAUSDT"

ADAData = pd.read_csv("./data/ADAUSDT.csv", date_parser = True)
ADAData.head()
# Out:
#              open_time     open     high      low    close       volume  \
# 0  2018-05-01 05:30:00  0.34145  0.34199  0.31870  0.32173  32463784.08
# 1  2018-05-01 09:30:00  0.32115  0.34300  0.32000  0.33787  14470581.61
# 2  2018-05-01 13:30:00  0.33756  0.35900  0.33421  0.34093  25321414.19
# 3  2018-05-01 17:30:00  0.34003  0.34290  0.33166  0.33735  16675168.68
# 4  2018-05-01 21:30:00  0.33776  0.35950  0.33714  0.35374  18237446.69
#
#             close_time           qav  num_trades  taker_base_vol  \
# 0  2018-05-01 09:29:59  1.052793e+07       16470     11783004.90
# 1  2018-05-01 13:29:59  4.781841e+06        8585      8615412.86
# 2  2018-05-01 17:29:59  8.811835e+06       15407     13381460.15
# 3  2018-05-01 21:29:59  5.623026e+06        9853      6992756.54
# 4  2018-05-02 01:29:59  6.407364e+06       11736      9571426.71
#
#    taker_quote_vol  ignore
# 0     3.834240e+06       0
# 1     2.843790e+06       0
# 2     4.655388e+06       0
# 3     2.359763e+06       0
# 4     3.360112e+06       0

# %%
ADAData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7656 entries, 0 to 7655
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   open_time        7656 non-null   object
#  1   open             7656 non-null   float64
#  2   high             7656 non-null   float64
#  3   low              7656 non-null   float64
#  4   close            7656 non-null   float64
#  5   volume           7656 non-null   float64
#  6   close_time       7656 non-null   object
#  7   qav              7656 non-null   float64
#  8   num_trades       7656 non-null   int64
#  9   taker_base_vol   7656 non-null   float64
#  10  taker_quote_vol  7656 non-null   float64
#  11  ignore           7656 non-null   int64
# dtypes: float64(8), int64(2), object(2)
# memory usage: 717.9+ KB

# %%
ADAData.describe()
# Out:
#               open         high          low        close        volume  \
# count  7656.000000  7656.000000  7656.000000  7656.000000  7.656000e+03
# mean      0.410231     0.418246     0.401605     0.410445  5.013877e+07
# std       0.672050     0.684811     0.658142     0.672290  5.771933e+07
# min       0.022300     0.023910     0.017650     0.022290  2.387484e+05
# 25%       0.048130     0.048980     0.047232     0.048137  1.774591e+07
# 50%       0.087930     0.089735     0.086045     0.087945  3.173024e+07
# 75%       0.233038     0.237992     0.226025     0.233015  5.919737e+07
# max       3.048000     3.101000     3.009000     3.048000  7.524809e+08
#
#                 qav    num_trades  taker_base_vol  taker_quote_vol  ignore
# count  7.656000e+03  7.656000e+03    7.656000e+03     7.656000e+03  7656.0
# mean   2.820788e+07  3.993751e+04    2.484427e+07     1.400023e+07     0.0
# std    6.907263e+07  8.239136e+04    2.891871e+07     3.464081e+07     0.0
# min    8.559022e+04  2.190000e+02    1.102618e+05     3.383928e+04     0.0
# 25%    1.200764e+06  3.822750e+03    8.926037e+06     5.864015e+05     0.0
# 50%    2.887390e+06  7.720500e+03    1.567452e+07     1.468243e+06     0.0
# 75%    1.762315e+07  3.388675e+04    2.905279e+07     8.614235e+06     0.0
# max    1.062536e+09  1.007609e+06    3.998935e+08     5.294195e+08     0.0

# %%
corr_close_time = ADAData.corr()["close"]
corr_close_time
# Out:
# open               0.999511
# high               0.999779
# low                0.999609
# close              1.000000
# volume             0.198755
# qav                0.653899
# num_trades         0.692928
# taker_base_vol     0.197737
# taker_quote_vol    0.646926
# ignore                  NaN
# Name: close, dtype: float64

# %%
plt.figure(figsize=(10, 7))
sns.heatmap(ADAData.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %%
ADAData.columns
# Out:
# Index(['open_time', 'open', 'high', 'low', 'close', 'volume', 'close_time',
#        'qav', 'num_trades', 'taker_base_vol', 'taker_quote_vol', 'ignore'],
#       dtype='object')

# %%
preparedData = ADAData[['open_time', 'open', 'high', 'low', 'close', 'volume', 'close_time']]
preparedData.head()
# Out:
#              open_time     open     high      low    close       volume  \
# 0  2018-05-01 05:30:00  0.34145  0.34199  0.31870  0.32173  32463784.08
# 1  2018-05-01 09:30:00  0.32115  0.34300  0.32000  0.33787  14470581.61
# 2  2018-05-01 13:30:00  0.33756  0.35900  0.33421  0.34093  25321414.19
# 3  2018-05-01 17:30:00  0.34003  0.34290  0.33166  0.33735  16675168.68
# 4  2018-05-01 21:30:00  0.33776  0.35950  0.33714  0.35374  18237446.69
#
#             close_time
# 0  2018-05-01 09:29:59
# 1  2018-05-01 13:29:59
# 2  2018-05-01 17:29:59
# 3  2018-05-01 21:29:59
# 4  2018-05-02 01:29:59

# %%
preparedData.to_csv(f"./preparedData/{symbol}.csv", index = None, header=True)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
symbol = "ADAUSDT"

ADAData = pd.read_csv(f"./data/{symbol}.csv", date_parser = True)
ADAData.head()
# Out:
#              open_time     open     high      low    close       volume  \
# 0  2018-05-01 05:30:00  0.34145  0.34199  0.31870  0.32173  32463784.08
# 1  2018-05-01 09:30:00  0.32115  0.34300  0.32000  0.33787  14470581.61
# 2  2018-05-01 13:30:00  0.33756  0.35900  0.33421  0.34093  25321414.19
# 3  2018-05-01 17:30:00  0.34003  0.34290  0.33166  0.33735  16675168.68
# 4  2018-05-01 21:30:00  0.33776  0.35950  0.33714  0.35374  18237446.69
#
#             close_time           qav  num_trades  taker_base_vol  \
# 0  2018-05-01 09:29:59  1.052793e+07       16470     11783004.90
# 1  2018-05-01 13:29:59  4.781841e+06        8585      8615412.86
# 2  2018-05-01 17:29:59  8.811835e+06       15407     13381460.15
# 3  2018-05-01 21:29:59  5.623026e+06        9853      6992756.54
# 4  2018-05-02 01:29:59  6.407364e+06       11736      9571426.71
#
#    taker_quote_vol  ignore
# 0     3.834240e+06       0
# 1     2.843790e+06       0
# 2     4.655388e+06       0
# ...

# %%
ADAData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7770 entries, 0 to 7769
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   open_time        7770 non-null   object
#  1   open             7770 non-null   float64
#  2   high             7770 non-null   float64
#  3   low              7770 non-null   float64
#  4   close            7770 non-null   float64
#  5   volume           7770 non-null   float64
#  6   close_time       7770 non-null   object
#  7   qav              7770 non-null   float64
#  8   num_trades       7770 non-null   int64
#  9   taker_base_vol   7770 non-null   float64
#  10  taker_quote_vol  7770 non-null   float64
#  11  ignore           7770 non-null   int64
# dtypes: float64(8), int64(2), object(2)
# memory usage: 728.6+ KB

# %%
ADAData.describe()
# Out:
#               open         high          low        close        volume  \
# count  7770.000000  7770.000000  7770.000000  7770.000000  7.770000e+03
# mean      0.433997     0.442249     0.425095     0.434185  4.986441e+07
# std       0.695037     0.707757     0.681152     0.695208  5.745523e+07
# min       0.022300     0.023910     0.017650     0.022290  2.387484e+05
# 25%       0.048685     0.049400     0.047675     0.048700  1.771199e+07
# 50%       0.089495     0.090900     0.087595     0.089555  3.152910e+07
# 75%       0.286087     0.293800     0.270975     0.286045  5.877842e+07
# max       3.048000     3.101000     3.009000     3.048000  7.524809e+08
#
#                 qav    num_trades  taker_base_vol  taker_quote_vol  ignore
# count  7.770000e+03  7.770000e+03    7.770000e+03     7.770000e+03  7770.0
# mean   2.874830e+07  4.087780e+04    2.470685e+07     1.426492e+07     0.0
# std    6.916989e+07  8.313822e+04    2.878355e+07     3.467609e+07     0.0
# ...

# %%
corr_close_time = ADAData.corr()["close"]
corr_close_time
# Out:
# open               0.999536
# high               0.999787
# low                0.999625
# close              1.000000
# volume             0.179782
# qav                0.641075
# num_trades         0.681577
# taker_base_vol     0.178832
# taker_quote_vol    0.634271
# ignore                  NaN
# Name: close, dtype: float64

# %%
plt.figure(figsize=(10, 7))
sns.heatmap(ADAData.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %%
ADAData.columns
# Out:
# Index(['open_time', 'open', 'high', 'low', 'close', 'volume', 'close_time',
#        'qav', 'num_trades', 'taker_base_vol', 'taker_quote_vol', 'ignore'],
#       dtype='object')

# %%
preparedData = ADAData[['open_time', 'open', 'high', 'low', 'close', 'volume', 'close_time']]
preparedData.head()
# Out:
#              open_time     open     high      low    close       volume  \
# 0  2018-05-01 05:30:00  0.34145  0.34199  0.31870  0.32173  32463784.08
# 1  2018-05-01 09:30:00  0.32115  0.34300  0.32000  0.33787  14470581.61
# 2  2018-05-01 13:30:00  0.33756  0.35900  0.33421  0.34093  25321414.19
# 3  2018-05-01 17:30:00  0.34003  0.34290  0.33166  0.33735  16675168.68
# 4  2018-05-01 21:30:00  0.33776  0.35950  0.33714  0.35374  18237446.69
#
#             close_time
# 0  2018-05-01 09:29:59
# 1  2018-05-01 13:29:59
# 2  2018-05-01 17:29:59
# 3  2018-05-01 21:29:59
# 4  2018-05-02 01:29:59

# %%
preparedData.to_csv(f"./preparedData/{symbol}.csv", index = None, header=True)
